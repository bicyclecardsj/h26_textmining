# %% [markdown]
# # 파이썬 클래스

# %%
class Account:
    #balance = 100 # 모든 초기값을 같게 하고 싶다면 이렇게 해도 괜찮음. 하지만 그래도 생성자로 하는게 더 좋음
    def __init__(self): # 멤버 변수 balance 초기화 -> 변수 선언
        self.balance = 0
    def deposit(self, amount):
        self.balance += amount
    def withdraw(self, amount):
        self.balance -= amount

a1 = Account()
a1.deposit(100)
a1.withdraw(50)
print('a1 : ', a1.balance)
# Out:
# a1 :  50

# %%
class Account:
    def __init__(self):
        self.__balance = 0
    def deposit(self, amount):
        self.__balance += amount
    def withdraw(self, amount):
        self.__balance -= amount
    def get_balance(self):
        return self.__balance

a1 = Account()
a1.deposit(100)
a1.withdraw(50)
print('a1 : ', a1.get_balance())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[12], line 14
#      12 a1.deposit(100)
#      13 a1.withdraw(50)
# ---> 14 print('a1 : ', a1.get_balance())
#
# TypeError: get_balance() takes 0 positional arguments but 1 was given
